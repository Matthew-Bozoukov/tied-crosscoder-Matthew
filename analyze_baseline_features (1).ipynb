# %%
import torch

import torch.nn as nn
import torch.nn.functional as F
from typing import Tuple
from typing import Callable, Any
import einops
class TopK(nn.Module):
    def __init__(self, k: int, postact_fn: Callable = nn.ReLU()) -> None:
        super().__init__()
        self.k = k
        self.postact_fn = postact_fn

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        topk = torch.topk(x, k=self.k, dim=-1)
        values = self.postact_fn(topk.values)
        # make all other values 0
        result = torch.zeros_like(x)
        result.scatter_(-1, topk.indices, values)
        return result

    def state_dict(self, destination=None, prefix="", keep_vars=False):
        state_dict = super().state_dict(destination, prefix, keep_vars)
        state_dict.update({prefix + "k": self.k, prefix + "postact_fn": self.postact_fn.__class__.__name__})
        return state_dict

    @classmethod
    def from_state_dict(cls, state_dict: dict[str, torch.Tensor], strict: bool = True) -> "TopK":
        k = state_dict["k"]
        postact_fn = ACTIVATIONS_CLASSES[state_dict["postact_fn"]]()
        return cls(k=k, postact_fn=postact_fn)
ACTIVATIONS_CLASSES = {
    "ReLU": nn.ReLU,
    "Identity": nn.Identity,
    "TopK": TopK,
}
class SAE(nn.Module):
  def __init__(self, batch_size: int,input_dim: int, expansion_factor: float = 8, device: str = 'cuda'): # Reorder arguments
        super().__init__()
        self.input_dim = input_dim
        self.latent_dim = 16384
        self.dtype=torch.float32
        self.W_dec = nn.Parameter(
            torch.nn.init.normal_(
                torch.empty(
                    self.latent_dim, input_dim, dtype=self.dtype
                )
            )
        )
        self.dtype=torch.float32
        #nn.init.kaiming_uniform_(self.decoder)
        self.W_enc = nn.Parameter(
            torch.empty( self.input_dim, self.latent_dim, dtype=self.dtype)  
        )
        self.W_dec.data = (
            self.W_dec.data / self.W_dec.data.norm(dim=-1, keepdim=True) * .08
        )
        self.W_enc.data = einops.rearrange(
            self.W_dec.data.clone(),
            "d_hidden d_model ->  d_model d_hidden",
        )
        self.b_enc = nn.Parameter(torch.zeros(self.latent_dim, dtype=self.dtype))
        self.b_dec = nn.Parameter(
            torch.zeros((self.input_dim), dtype=self.dtype)
        )
        self.batch_size=batch_size
        self.device=device
        self.l1_coefficient=3.2e-5
  def encode(self, x: torch.Tensor,k) -> torch.Tensor:
        
            
      
      topk=TopK(k=k)
      return topk(x@self.W_enc+self.b_enc)
  def decode(self,encoded: torch.Tensor)-> torch.Tensor:
        return encoded@self.W_dec+self.b_dec
  @torch.autocast(
        "cuda", dtype=torch.bfloat16, enabled=torch.cuda.is_bf16_supported() #speeds up forward by "2x"
    )
  def forward(self, x: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:
    encoded=self.encode(x,128)
    final=self.decode(encoded)
    reconstruction_error_BD = (final - x).pow(2)
    reconstruction_error_B = einops.reduce(reconstruction_error_BD, 'B D -> B', 'sum')
    l2_loss = reconstruction_error_B.mean()

    
    loss = l2_loss

    nonzeros_per_sample = encoded.count_nonzero(dim=1)       

    
    avg_nonzeros = nonzeros_per_sample.float().mean() 
    return final,encoded,loss,avg_nonzeros

# %%
pip install sae-vis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sae-vis
#   Downloading sae_vis-0.3.6-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.4 in /home/user/.local/lib/python3.12/site-packages (from sae-vis) (0.6.7)
# Collecting datasets<3.0.0,>=2.0.0 (from sae-vis)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: eindex-callum<0.2.0,>=0.1.0 in /home/user/.local/lib/python3.12/site-packages (from sae-vis) (0.1.2)
# Collecting einops<0.8.0,>=0.7.0 (from sae-vis)
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting jaxtyping<0.3.0,>=0.2.28 (from sae-vis)
#   Downloading jaxtyping-0.2.38-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.4 in /opt/anaconda3/lib/python3.12/site-packages (from sae-vis) (3.9.2)
# Requirement already satisfied: rich<14.0.0,>=13.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from sae-vis) (13.7.1)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sae-vis) (2.5.1)
# Requirement already satisfied: transformer-lens<3.0.0,>=2.0.0 in /home/user/.local/lib/python3.12/site-packages (from sae-vis) (2.15.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/user/.local/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.4->sae-vis) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/user/.local/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.4->sae-vis) (0.9.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (4.66.5)
# Requirement already satisfied: xxhash in /home/user/.local/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (3.5.0)
# Requirement already satisfied: multiprocess in /home/user/.local/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0,>=2.0.0->sae-vis) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /home/user/.local/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (0.31.2)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.0.0->sae-vis) (6.0.1)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/user/.local/lib/python3.12/site-packages (from jaxtyping<0.3.0,>=0.2.28->sae-vis) (0.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->sae-vis) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->sae-vis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->sae-vis) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->sae-vis) (1.4.4)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->sae-vis) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->sae-vis) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.4->sae-vis) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.1->sae-vis) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.1->sae-vis) (2.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->sae-vis) (4.11.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->sae-vis) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/user/.local/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->sae-vis) (1.13.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->sae-vis) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->sae-vis) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0.0,>=2.0.0->sae-vis) (1.3.0)
# Requirement already satisfied: accelerate>=0.23.0 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (1.7.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.0.3)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.0.3)
# Requirement already satisfied: sentencepiece in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.2.0)
# Requirement already satisfied: transformers>=4.43 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (4.51.3)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (4.4.2)
# Requirement already satisfied: wandb>=0.13.5 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.19.11)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer-lens<3.0.0,>=2.0.0->sae-vis) (5.9.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/user/.local/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-vis) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-vis) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-vis) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-vis) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-vis) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-vis) (1.11.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.1->sae-vis) (0.1.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets<3.0.0,>=2.0.0->sae-vis) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets<3.0.0,>=2.0.0->sae-vis) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.8.4->sae-vis) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.0.0->sae-vis) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.0.0->sae-vis) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.0.0->sae-vis) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.0.0->sae-vis) (2024.8.30)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.43->transformer-lens<3.0.0,>=2.0.0->sae-vis) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/user/.local/lib/python3.12/site-packages (from transformers>=4.43->transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.21.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.4->sae-vis) (1.0.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/user/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (3.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (4.25.3)
# Requirement already satisfied: pydantic<3 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (2.8.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/user/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (2.28.0)
# Requirement already satisfied: setproctitle in /home/user/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (1.3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.0.0->sae-vis) (2.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (4.0.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (2.20.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae-vis) (4.0.0)
# Downloading sae_vis-0.3.6-py3-none-any.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 21.7 MB/s eta 0:00:00 0:00:01
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 75.6 MB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
# Downloading jaxtyping-0.2.38-py3-none-any.whl (56 kB)
# Installing collected packages: jaxtyping, einops, datasets, sae-vis
#   Attempting uninstall: jaxtyping
#     Found existing installation: jaxtyping 0.3.2
#     Uninstalling jaxtyping-0.3.2:
#       Successfully uninstalled jaxtyping-0.3.2
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.1
#     Uninstalling einops-0.8.1:
#       Successfully uninstalled einops-0.8.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.6.0
#     Uninstalling datasets-3.6.0:
#       Successfully uninstalled datasets-3.6.0
# Successfully installed datasets-2.21.0 einops-0.7.0 jaxtyping-0.2.38 sae-vis-0.3.6
# Note: you may need to restart the kernel to use updated packages.

# %%
chat_dict=torch.load("gemma-2-2b-it-baseline_sae_layer_14_pre_resid-16384.pth")
base_dict=torch.load("gemma-2-2b-baseline_sae_layer_14_pre_resid-16384.pth")

chat_sae=SAE(8,2304).to('cuda')
base_sae=SAE(8,2304).to('cuda')
chat_sae.load_state_dict(chat_dict)
base_sae.load_state_dict(base_dict)
# Out:
# /tmp/ipykernel_1384/3479011816.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   chat_dict=torch.load("gemma-2-2b-it-baseline_sae_layer_14_pre_resid-16384.pth")
# /tmp/ipykernel_1384/3479011816.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   base_dict=torch.load("gemma-2-2b-baseline_sae_layer_14_pre_resid-16384.pth")
# <All keys matched successfully>

# %%
from transformer_lens import HookedTransformer

base_model = HookedTransformer.from_pretrained("google/gemma-2-2b").cuda()
chat_model = HookedTransformer.from_pretrained("google/gemma-2-2b-it").cuda()
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-2b-it")
# Out:
# WARNING:root:You tried to specify center_unembed=True for a model using logit softcap, but this can't be done! Softcapping is not invariant upon adding a constant Setting center_unembed=False instead.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# WARNING:root:You tried to specify center_unembed=True for a model using logit softcap, but this can't be done! Softcapping is not invariant upon adding a constant Setting center_unembed=False instead.
# Loaded pretrained model google/gemma-2-2b into HookedTransformer
# Moving model to device:  cuda
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model google/gemma-2-2b-it into HookedTransformer
# Moving model to device:  cuda

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds2 = load_dataset("lmsys/lmsys-chat-1m",token='your_token')['train']
len(ds2)
print(ds2[120]['conversation'][1]['content'])

_, cache = chat_model.run_with_cache(
                ds2[120]['conversation'][1]['content'],
                names_filter="blocks.14.hook_resid_pre",
                return_type=None,
            )
acts = cache["blocks.14.hook_resid_pre"]
print(acts.shape)
# Out:
# Using the latest cached version of the dataset since lmsys/lmsys-chat-1m couldn't be found on the Hugging Face Hub
# WARNING:datasets.load:Using the latest cached version of the dataset since lmsys/lmsys-chat-1m couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /home/user/.cache/huggingface/datasets/lmsys___lmsys-chat-1m/default/0.0.0/200748d9d3cddcc9d782887541057aca0b18c5da (last modified on Tue May 20 00:39:57 2025).
# WARNING:datasets.packaged_modules.cache.cache:Found the latest cached dataset configuration 'default' at /home/user/.cache/huggingface/datasets/lmsys___lmsys-chat-1m/default/0.0.0/200748d9d3cddcc9d782887541057aca0b18c5da (last modified on Tue May 20 00:39:57 2025).
# Hello! How can I assist you today?
# torch.Size([1, 10, 2304])

# %%
new=acts[0,:].squeeze(0)
size,_=new.shape
inputs = tokenizer(ds2[120]['conversation'][1]['content'], return_tensors="pt", truncation=True, padding=True).to('cuda')
for i in range(size):
    
    _,encoded,_,_=chat_sae(new[i,:].unsqueeze(0))
    values,indices=torch.topk(encoded,10)

    
        
    print(i)
    print(indices)
    print(tokenizer.decode(inputs['input_ids'][0][i]))
# Out:
# 0
# tensor([[11389,  9022, 10867,  9285,  4063, 11498, 10344,  6440,  5050, 15557]],
#        device='cuda:0')
# <bos>
# 1
# tensor([[11389,  9022, 10867,  9285,  4063,    22, 15719, 11498,  9873,  7449]],
#        device='cuda:0')
# Hello
# 2
# tensor([[ 8662,  4055,  9505,  7449, 11389,  9873, 11947,  7271,  8044, 15313]],
#        device='cuda:0')
# !
# 3
# tensor([[ 1138,  9873, 11389,  7449,  9505,  8662, 13715,  9022, 10867, 15313]],
#        device='cuda:0')
#  How
# 4
# tensor([[ 8807, 11389,  7449,  9505,  9873,  8662,  9022, 15313,  7904,   387]],
#        device='cuda:0')
#  can
# 5
# tensor([[ 9505,  7449, 11389,  8662,  7809, 13715,  9873,  9285,   387, 10867]],
#        device='cuda:0')
#  I
# 6
# tensor([[ 7257,  8662, 14637, 11389,  7449,  7904,  9873,  9505,  9022, 10867]],
#        device='cuda:0')
#  assist
# 7
# tensor([[ 8662,  9505,  8448, 11389,  7449,  7904, 13715,  9285,  9873,  9022]],
#        device='cuda:0')
#  you
# 8
# tensor([[ 5213,  8662, 11389,  9505, 12006,  7449,  7904, 11856,  9022,  9873]],
#        device='cuda:0')
#  today
# 9
# tensor([[ 8662,  7217,  7449,  9505, 12006,  7904, 11389,  5213,  9022,  9873]],
#        device='cuda:0')
# ?

# %%
pip install sae_lens
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sae_lens
#   Downloading sae_lens-5.10.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting automated-interpretability<1.0.0,>=0.0.5 (from sae_lens)
#   Downloading automated_interpretability-0.0.9-py3-none-any.whl.metadata (822 bytes)
# Collecting babe<0.0.8,>=0.0.7 (from sae_lens)
#   Downloading babe-0.0.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: datasets<3.0.0,>=2.17.1 in /home/user/.local/lib/python3.12/site-packages (from sae_lens) (2.21.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from sae_lens) (3.9.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.6 in /opt/anaconda3/lib/python3.12/site-packages (from sae_lens) (0.1.6)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/anaconda3/lib/python3.12/site-packages (from sae_lens) (3.9.1)
# Requirement already satisfied: plotly<6.0.0,>=5.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from sae_lens) (5.24.1)
# Collecting plotly-express<0.5.0,>=0.4.1 (from sae_lens)
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pytest-profiling<2.0.0,>=1.7.0 (from sae_lens)
#   Downloading pytest_profiling-1.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting python-dotenv<2.0.0,>=1.0.1 (from sae_lens)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from sae_lens) (6.0.1)
# Collecting pyzmq==26.0.0 (from sae_lens)
#   Downloading pyzmq-26.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Collecting safetensors<0.5.0,>=0.4.2 (from sae_lens)
#   Downloading safetensors-0.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting simple-parsing<0.2.0,>=0.1.6 (from sae_lens)
#   Downloading simple_parsing-0.1.7-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: transformer-lens<3.0.0,>=2.0.0 in /home/user/.local/lib/python3.12/site-packages (from sae_lens) (2.15.4)
# Requirement already satisfied: transformers<5.0.0,>=4.38.1 in /home/user/.local/lib/python3.12/site-packages (from sae_lens) (4.51.3)
# Collecting typer<0.13.0,>=0.12.3 (from sae_lens)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from sae_lens) (4.11.0)
# Collecting zstandard<0.23.0,>=0.22.0 (from sae_lens)
#   Downloading zstandard-0.22.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Collecting blobfile<3.0.0,>=2.1.1 (from automated-interpretability<1.0.0,>=0.0.5->sae_lens)
#   Downloading blobfile-2.1.1-py3-none-any.whl.metadata (15 kB)
# Collecting boostedblob<0.16.0,>=0.15.3 (from automated-interpretability<1.0.0,>=0.0.5->sae_lens)
#   Downloading boostedblob-0.15.6-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /opt/anaconda3/lib/python3.12/site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae_lens) (0.27.0)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /opt/anaconda3/lib/python3.12/site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae_lens) (1.26.4)
# Collecting orjson<4.0.0,>=3.10.1 (from automated-interpretability<1.0.0,>=0.0.5->sae_lens)
#   Downloading orjson-3.10.18-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae_lens) (1.5.1)
# Collecting tiktoken>=0.6.0 (from automated-interpretability<1.0.0,>=0.0.5->sae_lens)
#   Downloading tiktoken-0.9.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from babe<0.0.8,>=0.0.7->sae_lens) (2.2.2)
# Collecting py2store (from babe<0.0.8,>=0.0.7->sae_lens)
#   Downloading py2store-0.1.20.tar.gz (143 kB)
#   Preparing metadata (setup.py) ... done
# Collecting graze (from babe<0.0.8,>=0.0.7->sae_lens)
#   Downloading graze-0.1.29-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (3.13.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (4.66.5)
# Requirement already satisfied: xxhash in /home/user/.local/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (3.5.0)
# Requirement already satisfied: multiprocess in /home/user/.local/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0,>=2.17.1->sae_lens) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /home/user/.local/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (0.31.2)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from datasets<3.0.0,>=2.17.1->sae_lens) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.3->sae_lens) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.3->sae_lens) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.3->sae_lens) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.3->sae_lens) (1.4.4)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.3->sae_lens) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.3->sae_lens) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.8.3->sae_lens) (2.9.0.post0)
# Requirement already satisfied: traitlets in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib-inline<0.2.0,>=0.1.6->sae_lens) (5.14.3)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->sae_lens) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->sae_lens) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->sae_lens) (2024.9.11)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotly<6.0.0,>=5.19.0->sae_lens) (8.2.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotly-express<0.5.0,>=0.4.1->sae_lens) (0.14.2)
# Requirement already satisfied: scipy>=0.18 in /opt/anaconda3/lib/python3.12/site-packages (from plotly-express<0.5.0,>=0.4.1->sae_lens) (1.13.1)
# Requirement already satisfied: patsy>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from plotly-express<0.5.0,>=0.4.1->sae_lens) (0.5.6)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from pytest-profiling<2.0.0,>=1.7.0->sae_lens) (1.16.0)
# Requirement already satisfied: pytest in /opt/anaconda3/lib/python3.12/site-packages (from pytest-profiling<2.0.0,>=1.7.0->sae_lens) (7.4.4)
# Collecting gprof2dot (from pytest-profiling<2.0.0,>=1.7.0->sae_lens)
#   Downloading gprof2dot-2025.4.14-py3-none-any.whl.metadata (19 kB)
# Collecting docstring-parser<1.0,>=0.15 (from simple-parsing<0.2.0,>=0.1.6->sae_lens)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: accelerate>=0.23.0 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (1.7.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.0.3)
# Requirement already satisfied: einops>=0.6.0 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.7.0)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.2.38)
# Requirement already satisfied: rich>=12.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (13.7.1)
# Requirement already satisfied: sentencepiece in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.2.0)
# Requirement already satisfied: torch>=2.2 in /opt/anaconda3/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (2.5.1)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (4.4.2)
# Requirement already satisfied: wandb>=0.13.5 in /home/user/.local/lib/python3.12/site-packages (from transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.19.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/user/.local/lib/python3.12/site-packages (from transformers<5.0.0,>=4.38.1->sae_lens) (0.21.1)
# Collecting shellingham>=1.3.0 (from typer<0.13.0,>=0.12.3->sae_lens)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer-lens<3.0.0,>=2.0.0->sae_lens) (5.9.0)
# Collecting pycryptodomex~=3.8 (from blobfile<3.0.0,>=2.1.1->automated-interpretability<1.0.0,>=0.0.5->sae_lens)
#   Downloading pycryptodomex-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: urllib3<3,>=1.25.3 in /opt/anaconda3/lib/python3.12/site-packages (from blobfile<3.0.0,>=2.1.1->automated-interpretability<1.0.0,>=0.0.5->sae_lens) (2.2.3)
# Collecting lxml~=4.9 (from blobfile<3.0.0,>=2.1.1->automated-interpretability<1.0.0,>=0.0.5->sae_lens)
#   Downloading lxml-4.9.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting uvloop>=0.16.0 (from boostedblob<0.16.0,>=0.15.3->automated-interpretability<1.0.0,>=0.0.5->sae_lens)
#   Downloading uvloop-0.21.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.17.1->sae_lens) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.17.1->sae_lens) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.17.1->sae_lens) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.17.1->sae_lens) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.17.1->sae_lens) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.17.1->sae_lens) (1.11.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.12/site-packages (from httpx<0.28.0,>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae_lens) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx<0.28.0,>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae_lens) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<0.28.0,>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae_lens) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from httpx<0.28.0,>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae_lens) (3.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from httpx<0.28.0,>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae_lens) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae_lens) (0.14.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/user/.local/lib/python3.12/site-packages (from jaxtyping>=0.2.11->transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.1.6)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->babe<0.0.8,>=0.0.7->sae_lens) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->babe<0.0.8,>=0.0.7->sae_lens) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.17.1->sae_lens) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=12.6.0->transformer-lens<3.0.0,>=2.0.0->sae_lens) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=12.6.0->transformer-lens<3.0.0,>=2.0.0->sae_lens) (2.15.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=1.2.0->automated-interpretability<1.0.0,>=0.0.5->sae_lens) (3.5.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=2.2->transformer-lens<3.0.0,>=2.0.0->sae_lens) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/user/.local/lib/python3.12/site-packages (from torch>=2.2->transformer-lens<3.0.0,>=2.0.0->sae_lens) (1.13.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=2.2->transformer-lens<3.0.0,>=2.0.0->sae_lens) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=2.2->transformer-lens<3.0.0,>=2.0.0->sae_lens) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.2->transformer-lens<3.0.0,>=2.0.0->sae_lens) (1.3.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/user/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (3.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (4.25.3)
# Requirement already satisfied: pydantic<3 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (2.8.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/user/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (2.28.0)
# Requirement already satisfied: setproctitle in /home/user/.local/lib/python3.12/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (1.3.6)
# Collecting dol (from graze->babe<0.0.8,>=0.0.7->sae_lens)
#   Downloading dol-0.3.16-py3-none-any.whl.metadata (18 kB)
# Collecting config2py (from py2store->babe<0.0.8,>=0.0.7->sae_lens)
#   Downloading config2py-0.1.37-py3-none-any.whl.metadata (14 kB)
# Collecting importlib_resources (from py2store->babe<0.0.8,>=0.0.7->sae_lens)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.12/site-packages (from pytest->pytest-profiling<2.0.0,>=1.7.0->sae_lens) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/anaconda3/lib/python3.12/site-packages (from pytest->pytest-profiling<2.0.0,>=1.7.0->sae_lens) (1.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (4.0.7)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.1.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (2.20.1)
# Collecting i2 (from config2py->py2store->babe<0.0.8,>=0.0.7->sae_lens)
#   Downloading i2-0.1.46-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=2.2->transformer-lens<3.0.0,>=2.0.0->sae_lens) (2.1.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.0.0->sae_lens) (4.0.0)
# Downloading sae_lens-5.10.3-py3-none-any.whl (131 kB)
# Downloading pyzmq-26.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (911 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.2/911.2 kB 96.9 MB/s eta 0:00:00
# Downloading automated_interpretability-0.0.9-py3-none-any.whl (66 kB)
# Downloading babe-0.0.7-py3-none-any.whl (6.9 kB)
# Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Downloading pytest_profiling-1.8.1-py3-none-any.whl (9.9 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading safetensors-0.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (434 kB)
# Downloading simple_parsing-0.1.7-py3-none-any.whl (112 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
# Downloading zstandard-0.22.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 139.8 MB/s eta 0:00:00
# Downloading blobfile-2.1.1-py3-none-any.whl (73 kB)
# Downloading boostedblob-0.15.6-py3-none-any.whl (59 kB)
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading orjson-3.10.18-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading tiktoken-0.9.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 120.6 MB/s eta 0:00:00
# Downloading gprof2dot-2025.4.14-py3-none-any.whl (37 kB)
# Downloading graze-0.1.29-py3-none-any.whl (19 kB)
# Downloading lxml-4.9.4-cp312-cp312-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 75.3 MB/s eta 0:00:00
# Downloading pycryptodomex-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 139.3 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 119.0 MB/s eta 0:00:00
# Downloading config2py-0.1.37-py3-none-any.whl (32 kB)
# Downloading dol-0.3.16-py3-none-any.whl (254 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading i2-0.1.46-py3-none-any.whl (202 kB)
# Building wheels for collected packages: py2store
#   Building wheel for py2store (setup.py) ... done
#   Created wheel for py2store: filename=py2store-0.1.20-py3-none-any.whl size=118410 sha256=f013adbbfeb57293923b22964206b0c50633726db14c6813da473f09f6cc642a
#   Stored in directory: /home/user/.cache/pip/wheels/1e/18/b7/d110b0463b49932e627228cc80386373e6766baa5b0feba2dc
# Successfully built py2store
# Installing collected packages: i2, dol, zstandard, uvloop, shellingham, safetensors, pyzmq, python-dotenv, pycryptodomex, orjson, lxml, importlib_resources, gprof2dot, docstring-parser, config2py, tiktoken, simple-parsing, pytest-profiling, py2store, graze, blobfile, typer, boostedblob, babe, plotly-express, automated-interpretability, sae_lens
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.5.3
#     Uninstalling safetensors-0.5.3:
#       Successfully uninstalled safetensors-0.5.3
# Successfully installed automated-interpretability-0.0.9 babe-0.0.7 blobfile-2.1.1 boostedblob-0.15.6 config2py-0.1.37 docstring-parser-0.16 dol-0.3.16 gprof2dot-2025.4.14 graze-0.1.29 i2-0.1.46 importlib_resources-6.5.2 lxml-4.9.4 orjson-3.10.18 plotly-express-0.4.1 py2store-0.1.20 pycryptodomex-3.23.0 pytest-profiling-1.8.1 python-dotenv-1.1.0 pyzmq-26.0.0 sae_lens-5.10.3 safetensors-0.4.5 shellingham-1.5.4 simple-parsing-0.1.7 tiktoken-0.9.0 typer-0.12.5 uvloop-0.21.0 zstandard-0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sae_vis.data_config_classes import SaeVisConfig
test_feature_idx = [11328]#[147, 507, 963, 994, 1383, 2026, 3738, 3982, 5044, 6310, 6348, 6518, 6592, 6918, 6983, 7079, 7748, 8081, 8489, 8752, 9034, 9134, 9291, 9418, 10335, 10615, 11379, 13708, 14643, 16379]
sae_vis_config = SaeVisConfig(
    features = 7257,
    minibatch_size_tokens=8,
    minibatch_size_features=32,
)

from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
tokens = torch.load('datasets/lmsys_1m_tokens.pt')
from sae_lens import SAE, HookedSAETransformer, SAEConfig
model = HookedSAETransformer.from_pretrained("google/gemma-2-2b-it")
cfg = SAEConfig(
            architecture="standard",
            # forward pass details.
            d_in=2304,
            d_sae=16384,
            activation_fn_str="topk",
            activation_fn_kwargs={"k": 128},
            apply_b_dec_to_input=False,
            finetuning_scaling_factor=False,
            # dataset it was trained on details.
            context_size=1024,
            model_name='google/gemma-2-2b-it',
            hook_name='blocks.14.hook_resid_pre',
            hook_layer=14,
            hook_head_index=None,
            prepend_bos=True,
            dataset_path='lmsys/lmsys-chat-1m',
            dataset_trust_remote_code=False,
            normalize_activations="None",
            # misc
            sae_lens_training_version=None,
            dtype="float32",
            device='cuda',
        )
sae = SAE(cfg)
sae.load_state_dict(chat_dict)
from sae_vis.data_storing_fns import SaeVisData
sae_vis_data = SaeVisData.create(
    sae=sae,
    model=model,
    tokens=tokens[:4096],  # 8192
    cfg=sae_vis_config  # 256
)
# Out:
# /tmp/ipykernel_1384/2662301747.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   tokens = torch.load('datasets/lmsys_1m_tokens.pt')
# WARNING:root:You tried to specify center_unembed=True for a model using logit softcap, but this can't be done! Softcapping is not invariant upon adding a constant Setting center_unembed=False instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model google/gemma-2-2b-it into HookedTransformer

# %%
sae_vis_data.save_feature_centric_vis(filename="demo_feature_vis.html", feature=7257)
